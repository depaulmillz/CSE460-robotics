# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
! ls
# Out:
# DataDescriptions.py   optitrack_test.py     part3_q3_results.csv
# MoCapData.py          part2.py              part3_q4.py
# NatNetClient.py       part2res.csv          robot_control_test.py
# Plots.ipynb           part3_q1_2.py         spline.csv
# __pycache__           part3_q2_q1_res.csv   util.py
# apis.py               part3_q3.py

# %%
part2 = pd.read_csv('part2res.csv')
part2['angle'] = part2['angle'] / np.pi * 180
part3_q2_q1 = pd.read_csv('part3_q2_q1_res.csv')
part3_q3 = pd.read_csv('part3_q3_results.csv')
part3_q4 = pd.read_csv('spline.csv')

# %%
ax = plt.axes()
plt.grid()
ax.plot(part2['time'],part2['angle'], '-g')
ax2 = ax.twinx()
ax2.plot(part2['time'],part2['dist'], '-b')
plt.show()

# %%
ax = plt.axes()
ax.grid()
ax.plot(part3_q2_q1['robotx'], '-r')
ax.plot(part3_q2_q1['desiredx'], '-b')
plt.show()

# %%
ax = plt.axes()
ax.grid()
ax.plot(part3_q2_q1['roboty'], '-r')
ax.plot(part3_q2_q1['desiredy'], '-b')
plt.show()

# %%
ax = plt.axes()
ax.grid()
ax.plot(part3_q3['robotx'], '-r')
ax.plot(part3_q3['desiredx'], '-b')
plt.show()

# %%
ax = plt.axes()
ax.grid()
ax.plot(part3_q3['roboty'], '-r')
ax.plot(part3_q3['desiredy'], '-b')
plt.show()

# %%
ax = plt.axes()
ax.grid()
ax.plot(part3_q4['robotx'], '-r')
ax.plot(part3_q4['desiredx'], '-b')
plt.show()

# %%
ax = plt.axes()
ax.grid()
ax.plot(part3_q4['roboty'], '-r')
ax.plot(part3_q4['desiredy'], '-b')
plt.show()
